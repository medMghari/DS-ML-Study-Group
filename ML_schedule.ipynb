# %%
import pandas as pd

# %%
data = pd.read_csv("ML_Links.csv")

# %%
data = data[["Event", "Youtube Link"]]

# %% [markdown]
# # Introduction And ML Models

# %%
intro = data.iloc[:11]
intro
# Out:
#                                   Event                  Youtube Link
# 0      Introduction to Machine Learning  https://youtu.be/9J6FNvil6Gw
# 1           1.2.1 Intro to Scikit-learn  https://youtu.be/ecryKgFv5MA
# 2                      1.2.2 Predictors  https://youtu.be/AHALKrsFdVw
# 3      1.2.3 Transformers and Pipelines  https://youtu.be/zVU4131QPsw
# 4                  1.2.4 Feature Unions  https://youtu.be/_gOyCmdumps
# 5             1.2.5 Custom Transformers  https://youtu.be/I0YbI9x51kU
# 6               1.2.6 Custom Predictors  https://youtu.be/bxf2JHcH4UI
# 7   1.2.7 Exercise Distance Transformer  https://youtu.be/0zYnOu1axGQ
# 8    1.2.8 Exercise Majority Classifier  https://youtu.be/SGLjDeJqDb0
# 9           1.3.1 Persisting Your Model  https://youtu.be/V9Pm_EZvABA
# 10                1.3.2 Common Mistakes  https://youtu.be/YZQNIUIAi3A

# %% [markdown]
# # Supervised Learning : Models And Metrics

# %%
sup = data.iloc[11:30]
sup
# Out:
#                                      Event                  Youtube Link
# 11                2.1.1 Regression Metrics  https://youtu.be/wlMrMvphMuw
# 12           2.2.1 Linear Regression Intro  https://youtu.be/L1h6cIG8XcA
# 13   2.2.2 Gradient Descent and Huber Loss  https://youtu.be/j0d4RogPiXM
# 14           2.2.3 Multivariate Regression  https://youtu.be/9YZbXipwAQg
# 15                2.2.4 Feature Importance  https://youtu.be/x5XB1ynjCGI
# 16            2.3.1 Classification Metrics  https://youtu.be/SMmbzWn8yGI
# 17  2.3.2 Probabilistic Models and Metrics  https://youtu.be/4MgWh8oD-hQ
# 18               2.3.3 Logistic Regression  https://youtu.be/oqj-0_4WKq4
# 19               2.3.4 Multiclassification  https://youtu.be/gOVP8c1Cmmg
# 20                   2.4.1 Model Selection  https://youtu.be/lEBStVJXXpM
# 21           2.4.2 Intro to Decision Trees  https://youtu.be/D6tNPIXCI1o
# 22      2.4.3 Underfitting and Overfitting  https://youtu.be/ZhhvoUAhA80
# ...

# %% [markdown]
# # Preprocessing

# %%
prp = data.iloc[30:38]
prp
# Out:
#                                        Event                  Youtube Link
# 30  3.1.1 Feature Engineering and Extraction  https://youtu.be/kHDRaKe2B5A
# 31              3.1.2 Feature Transformation  https://youtu.be/YAJsJNS3DAA
# 32             3.1.3 Curse of Dimensionality  https://youtu.be/HvG45qVJM84
# 33                      3.1.4 Regularization  https://youtu.be/ArJqhJ415d4
# 34           3.1.5 Multicollinearity and PCA  https://youtu.be/8eBKta-D334
# 35                     3.1.6 Ensemble Models  https://youtu.be/oUOi5T1b_iU
# 36                   3.2.1 Bias and Variance  https://youtu.be/-ZLg6Zp9HHg
# 37                     3.2.2 Learning Curves  https://youtu.be/KB4fPj68Rbo

# %% [markdown]
# # KNN

# %%
knn = data.iloc[38:42]
knn
# Out:
#                           Event                  Youtube Link
# 38              3.3.1 Intro KNN  https://youtu.be/EV6xlHdTaEY
# 39  3.3.2 KNN Bias and Variance  https://youtu.be/AXbhiyWJZdw
# 40    3.3.3 KNN Time Complexity  https://youtu.be/XleyueB7jXU
# 41   3.3.4 KD Trees and Weights  https://youtu.be/UV1WeqUFPE8

# %% [markdown]
# # NLP

# %%
nlp = data.iloc[42:54]
nlp
# Out:
#                            Event                  Youtube Link
# 42            3.4.1 Intro to NLP  https://youtu.be/w3HtykbMcqk
# 43                   3.4.2 Spacy  https://youtu.be/7nojkNN0EME
# 44      3.4.3 Obtaining a Corpus  https://youtu.be/4mYBqqbW408
# 45      3.4.4 Bag of Words Model  https://youtu.be/7bKNknkmIJI
# 46      3.4.5 Hashing Vectorizer  https://youtu.be/_wPHgQhiMVY
# 47                  3.4.6 TF-IDF  https://youtu.be/kv9cE-uOnis
# 48        3.4.7 Improving Signal  https://youtu.be/UR4JcVOBiAI
# 49  3.4.8 N-grams and Similarity  https://youtu.be/tuwCNPEFRDs
# 50   3.4.9 Word Usage Classifier  https://youtu.be/FNU4dNeKrHo
# 51             3.4.10 Exercise I  https://youtu.be/kAZuP3efPbg
# 52            3.4.11 Exercise II  https://youtu.be/MkpFJkSrC2o
# 53    3.4.12 Exercise III and IV  https://youtu.be/Uw1_iZgihC0

# %% [markdown]
# # Decision Trees

# %%
dt = data.iloc[54:60]
dt
# Out:
#                                                 Event  \
# 54                      4.1.1 Intro to Decision Trees
# 55                           4.1.2 Tree Error Metrics
# 56                         4.1.3 Trees for Regression
# 57           4.1.4 Training Trees and Hyperparameters
# 58  4.1.5 Geometric Interpretation and Time Comple...
# 59                    4.1.6 Time Complexity Continued
#
#                     Youtube Link
# 54  https://youtu.be/4cIr8W9tXD8
# 55  https://youtu.be/Pv8bnN3E4xA
# 56  https://youtu.be/LvUazyMSRFM
# 57  https://youtu.be/nC-pHG_hgdY
# 58  https://youtu.be/l23BnV-4Xwc
# 59  https://youtu.be/oD_INvReM_I

# %% [markdown]
# # Random Forests

# %%
rf = data.iloc[60:66]
rf
# Out:
#                                 Event                  Youtube Link
# 60               4.1.7 Random Forests  https://youtu.be/JUzss0-pvz8
# 61       4.1.8 Extreme Random Forests  https://youtu.be/GLjopN8Lw94
# 62    4.1.9 Gradient Boosting Trees I  https://youtu.be/KJtV7fTrFH4
# 63  4.1.10 Gradient Boosting Trees II  https://youtu.be/E2R4D2Gc4x4
# 64          4.1.11 Feature Importance  https://youtu.be/WDLvgw-Znmg
# 65                   4.1.12 Exercises  https://youtu.be/7q3pk2VcDFQ

# %% [markdown]
# # SVM

# %%
svm = data.iloc[66:80]
svm
# Out:
#                                          Event                  Youtube Link
# 66                          5.1.1 Intro to SVM  https://youtu.be/GxSSq1B-BHg
# 67             5.1.2 Largest Margin Classifier  https://youtu.be/EK-69gK8y9E
# 68                5.1.3 Soft Margin Classifier  https://youtu.be/QT-Flust1Hc
# 69                           5.1.4 SVM Kernels  https://youtu.be/VQWkkPV1Q_Q
# 70            5.1.5 SVM vs Logistic Regression  https://youtu.be/4G7uEZCAr2U
# 71                        5.1.6 SVM Regression  https://youtu.be/xp8TJgzgWp0
# 72                   5.1.7 SVM Lagrangian Dual  https://youtu.be/defq3yJ8cyw
# 73                          5.1.8 Kernel Trick  https://youtu.be/YcRcxm4LSqg
# 74    5.1.9 SVM Time Complexity and Multiclass  https://youtu.be/FR5D4A3Nn0c
# 75   5.1.10 SVM Tuning Kernels Exercise Part I  https://youtu.be/MggSYvtMcLQ
# 76  5.1.11 SVM Tuning Kernels Exercise Part II  https://youtu.be/tvWb6XObsFg
# ...

# %% [markdown]
# # Clustering

# %%
cluster = data.iloc[80:87]
cluster
# Out:
#                                          Event                  Youtube Link
# 80                   5.2.1 Intro to Clustering  https://youtu.be/HktZtB7Te0c
# 81                5.2.2 Metrics for Clustering  https://youtu.be/kWsylUt8LxA
# 82                     5.2.3 KMeans Clustering  https://youtu.be/_OKUAiC9FLY
# 83                           5.2.4 Elbow Plots  https://youtu.be/J_jH7cXGUSQ
# 84               5.2.5 Gaussian Mixture Models  https://youtu.be/WwDiKfHW52U
# 85  5.2.6 Choosing Cluster Based on Silhouette  https://youtu.be/Gj4HHh4dDEk
# 86     5.2.7 GMM Choosing Number of Components  https://youtu.be/QO3F4lBs4m4

# %% [markdown]
# # Time Series

# %%
ts = data.iloc[87:99]
ts
# Out:
#                                     Event                  Youtube Link
# 87             6.1.1 Intro to Time Series  https://youtu.be/BvDcWoLnWFk
# 88   6.1.2 Crossvalidation in Time Series  https://youtu.be/ZOJAof-3YYA
# 89                6.1.3 Stationary Signal  https://youtu.be/WytJdsQBeos
# 90                   6.1.4 Modeling Drift  https://youtu.be/53FLb9usJBk
# 91        6.1.5 Fourier Transforms Part I  https://youtu.be/k-cF7LB7p4w
# 92       6.1.6 Fourier Transforms Part II  https://youtu.be/7KSdhV2elq8
# 93  6.1.7 Fourier Components in our Model  https://youtu.be/ek3vt4xLL-k
# 94                   6.1.8 Modeling Noise  https://youtu.be/IBBcCxCPv1w
# 95                6.1.9 Moving Statistics  https://youtu.be/8LUt3PBcCFk
# 96                      6.1.10 Full Model  https://youtu.be/oIIE1Fh8eNc
# 97                  6.1.11 ARMA and ARIMA  https://youtu.be/UPox0nn4IvE
# 98                      6.1.12 AR Example  https://youtu.be/GaQ70ZHo69s

# %% [markdown]
# # Dimension Reduction

# %%
dr = data.iloc[99:112]
dr
# Out:
#                                        Event                  Youtube Link
# 99        6.2.1 Intro to Dimension Reduction  https://youtu.be/b5BihaS90q0
# 100                6.2.2 Math of Projections  https://youtu.be/CZjSrCpkxxk
# 101                                6.2.3 PCA  https://youtu.be/dCYH6MVyfSA
# 102                6.2.4 PCA in Scikit Learn  https://youtu.be/lSxcJbaRvkA
# 103         6.2.5 PCA Implementation Details  https://youtu.be/QQl4h1gyCwc
# 104  6.2.6 Choosing the Number of Components  https://youtu.be/4azFI2QzyXU
# 105                      6.2.7 Truncated SVD  https://youtu.be/nfwInvCoym0
# 106                                6.2.8 NMF  https://youtu.be/ELLDyWiiSXU
# 107       6.2.9 Using PCA with Supervised ML  https://youtu.be/u8tUlG28CH0
# 108             6.2.10 PCA for Visualization  https://youtu.be/MRwKUI5ulio
# 109               6.2.11 NMF Exercise Part I  https://youtu.be/oo1sDDHE-DM
# ...

# %% [markdown]
# # Anomaly Detection

# %%
ad = data.iloc[112:125]
ad
# Out:
#                                                  Event  \
# 112                   7.1.1 Intro to Anomaly Detection
# 113                                7.1.2 One class SVM
# 114                             7.1.3 Isolation Forest
# 115  7.1.4 Comparison Between One-class SVM and Iso...
# 116                          7.1.5 Intro to Case Study
# 117                7.1.6 Initial Baseline Model Part I
# 118               7.1.7 Initial Baseline model Part II
# 119                          7.1.8 Full Baseline Model
# 120                            7.1.9 Z-score Detection
# 121                   7.1.10 Rolling Z-score Detection
# 122       7.1.11 Using External Features Initial Model
# 123    7.1.12 Using External Features Tuning the Model
# 124  7.1.13 Packaging the Time Series Anomaly Detector
#
#                      Youtube Link
# 112  https://youtu.be/KuFUQ7wWhsY
# 113  https://youtu.be/2l0TD7gCzvQ
# 114  https://youtu.be/xIAwOj_xh9s
# 115  https://youtu.be/VIyK4gLB2hg
# ...

# %% [markdown]
# # Model Considerations

# %%
mc = data.iloc[125:138]
mc
# Out:
#                                               Event  \
# 125                      8.1.1 Model Considerations
# 126                         8.1.2 Model Development
# 127               8.1.3 Flask App Local Development
# 128                              8.1.4 GET requests
# 129            8.1.5 Making GET Requests with Model
# 130      8.1.6 Using our Model with Twitter Web API
# 131         8.1.7 POST Requests and Flask Templates
# 132       8.1.8 Preparing for Deployment to the Web
# 133  8.1.9 Deploying our App to the Web with Heroku
# 134                   8.2.1 Rethinking Model Tuning
# 135                    8.2.2 Intro to Bayes Theorem
# 136                        8.2.3 Bayesian Inference
# 137                     8.2.4 Bayesian Optimization
#
#                      Youtube Link
# 125  https://youtu.be/SFFFnqugdOQ
# 126  https://youtu.be/DrClE-USVDg
# 127  https://youtu.be/chRA6Lngw-A
# 128  https://youtu.be/v1yYLbB_uUE
# 129  https://youtu.be/q9DgF7mJbrc
# ...
